# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import os

import time

urlList = set()
areaList = set()

basicArea = ['jiangan', 'jianghan', 'qiaokou', 'dongxihu', 'wuchang', 'qingshan', 'hongshan', 'donghugaoxin',
             'jiangxia', 'caidian', 'huangbei', 'xinzhou','zhuankoukaifaqu']
headers = {'User-Agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWekit 537.36 (KHTML, like Gecko) Chrome",
            "Accept" : "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"}

def getSubUrl(basicArea):
    global areaList
    for area in basicArea:
        print('现在进行到' + area)
        url = 'http://wh.lianjia.com/ershoufang/' + area
        areaHtml = urlopen(url)
        bsObj = BeautifulSoup(areaHtml)
        print(url)
        aList = bsObj.select('div[data-role="ershoufang"]')[0].findAll('div')[1].findAll('a')
        for a in aList:
            if a['href'] not in areaList:
                areaList.add(a['href'][12:-1])
    with open('./lianjia/subAreaList', 'a+') as subAreaList:
        for area in areaList:
            subAreaList.write(area + '\n')

def scrapHouse(areaList):
    global urlList
    for area in areaList:
        with open('./lianjia/' + area, 'a+') as txtFile:
            basicUrl = 'https://wh.lianjia.com/ershoufang/' + area
            print('\n\n现在进行到' + area )
            pageNum = getPageNum(basicUrl)
            for num in range(1, pageNum+1):
                url = basicUrl + '/pg' + str(num)
                html = urlopen(url)
                try:
                    html = urlopen(url)
                    bsObj = BeautifulSoup(html)
                    listLen = len(bsObj.select('ul[class^="sell"]')[0].findAll('li'))
                    linkdivs = bsObj.select('div[class=title]')[1:listLen+1]
                    for div in linkdivs:
                        link = div.a['href']
                        if link not in urlList:
                            urlList.add(link)
                            txtFile.write(link + '\n')
                    print('地区:' + area + '第' + str(num) + '页爬取成功\n')
                except:
                    print('地区:' + area + '第' + str(num) + '页爬取失败\n')


def getPageNum(url):
    html = urlopen(url)
    bsObj = BeautifulSoup(html)
    num = eval(bsObj.select('div[page-data]')[0]['page-data'])['totalPage']
    return num

def updateData():
    pass

#getSubUrl(basicArea)
#scrapHouse(areaList)

# %%
import csv
import codecs
from bs4 import BeautifulSoup
import os
from urllib.request import urlopen
import re
headList = ['房屋类型', '所在楼层', '建筑面积', '户型结构', '套内面积', '建筑类型', '房屋朝向', '建筑结构', '装修情况', '梯户比例', '是否配备电梯', '产权年限', '挂牌时间', '交易权属', '上次交易', '房屋用途', '是否满两年', '产权所属(是否共有)', '抵押信息', '房本备件', '小区名', '首付', '税费', '挂牌价', '单价','url']
# sourceFile = './lianjia/baibuting'
def scrapData(sourceFile, targetCSVFile = './lianjia.csv'):
    with codecs.open(targetCSVFile, 'a+', 'utf-8') as csvFile:
        writer = csv.writer(csvFile)
        #writer.writerow(headList)
        with open(sourceFile , 'r') as urlFile:
            urlList = urlFile.read().split('\n')
        for url in urlList:
            #print('正在进行' + url)
            try:
                html = urlopen(url)
                bsObj = BeautifulSoup(html)
                writer.writerow(cleanData(bsObj, url))
                #print('url:' + url + '成功')
            except:
                print('\nurl:' + url + '失败\n')
                
# 写csv文件的头
def writeHead(targetCSVFile='./lianjia.csv'):
    with codecs.open(targetCSVFile, 'w', 'utf-8') as csvFile:
        writer = csv.writer(csvFile)
        writer.writerow(headList)
sourceFile = './lianjia/baibuting'
#scrapData(sourceFile, './experiment.csv')

# %%
# 数据整理
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re
def cleanData(bsObj, url):
    data = list()
    # 基本信息
    a = bsObj.select_one('div[class="base"] div[class="content"]').get_text().replace(' ', '').replace('\n\n', '').split('\n')
    # 交易属性
    b = bsObj.select_one('div[class="transaction"] div[class="content"]').get_text().replace(' ', '').replace('\n', ' ').replace('  ', ' ').replace('  ', ' ').split(' ')[1:-1][1::2]   
    # 小区位置
    c = bsObj.select_one('div[class="communityName"] a').get_text()
    # 税费
    d = bsObj.select_one('span[class="taxtext"]').get_text()
    # 总价
    e = bsObj.select_one('span[class="total"]').get_text()
    # 单价
    f = bsObj.select_one('span[class="unitPriceValue"]').get_text()
    for num in range(0, len(a)):
        if num == 2 or num == 4 or num == 11:
            if re.findall('[0-9.]+', a[num]):
                data += re.findall('[0-9.]+', a[num])
            else:
                data.append(a[num][4:])
        #elif num == 10:
        #    if a[num] == '有':
        #        data.append(True)
        #    else:
        #        data.append(False)
        else:
            data.append(a[num][4:])
    #if b[4] == '未满两年':
    #    b[4] = False
    #else:
    #    b[4] = True
    #if b[5] == '非共有':
    #    b[5] = False
    #else:
    #    b[5] = True
    data += b
    data.append(c)
    data += re.findall('[0-9.]+',d)
    data += re.findall('[0-9.]+',e)
    data += re.findall('[0-9.]+',f)   
    #numlist = [2,4,11,21,22,23,24]
    #for num in numlist:
    #    data[num] = float(data[num])
    data.append(url)
    return data
#html= urlopen('https://wh.lianjia.com/ershoufang/104101085322.html')

#obj = BeautifulSoup(html)
#print(obj)
#print(cleanData(BeautifulSoup(html), 'https://wh.lianjia.com/ershoufang/104101085322.html'))
# 房屋类型, 所在楼层, 建筑面积, 户型结构, 套内面积, 建筑类型, 房屋朝向, 建筑结构, 装修情况, 梯户比例, 是否配备电梯, 产权年限, 挂牌时间, 交易权属, 上次交易, 房屋用途, 是否满两年, 产权所属(是否共有), 抵押信息, 房本备件, 小区名, 首付, 税费, 挂牌价, 单价
# Out:
# <!DOCTYPE html>
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="no-transform" http-equiv="Cache-Control"/><meta content="no-siteapp" http-equiv="Cache-Control"/><meta content="zh-CN" http-equiv="Content-language"/><meta content="telephone=no" name="format-detection"/><meta content="pc" name="applicable-device"/><link href="https://m.lianjia.com/wh/ershoufang/104101085322.html" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta content="format=html5;url=https://m.lianjia.com/wh/ershoufang/104101085322.html" name="mobile-agent"/><script>
# ljConf = {
#     city_id: '420100',
#     city_abbr: 'wh',
#     city_name: '武汉',
#     channel: 'ershoufang',
#     page: 'ershoufang_view',
#     pageConfig: {"ajaxroot":"\/\/ajax.api.lianjia.com\/","imAppid":"LIANJIA_WEB_20160624","imAppkey":"6dfdcee27d78b1107fceeca55d80b7bd"},
#     feroot: '//s1.ljcdn.com/feroot/',
#     ucid:'',
#     cdn:'0',
# };
# </script>
# <!-- 2017.11.8 市场需求加上新的统计 -->
# <!-- 2017.7.18 开放全国 -->
# <script>
# var _hmt = _hmt || [];
# (function() {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?9152f8221cb6243a53c83b956842be8a";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();
# </script>
# <script src="https://s1.ljcdn.com/feroot/pc/asset/common/tingyun-rum.js?_v=201809070048259"></script><title>高层观景房 可望江 中间位置 安静不临街_武汉百步亭银泰御华园一期二手房推荐(武汉链家网)</title>
# <meta content="武汉链家网高层观景房 可望江 中间位置 安静不临街二手房房源推荐，百步亭银泰御华园一期优质二手房房源推荐，挑选百步亭银泰御华园一期优质二手房就到武汉链家网." name="description"/>
# <meta content="高层观景房 可望江 中间位置 安静不临街二手房,武汉百步亭银泰御华园一期推荐二手房房源,银泰御华园一期优质二手房" name="keywords"/>
# <link href="https://wh.lianjia.com/ershoufang/104101085322.html" rel="canonical"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/><link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link href="https://s1.ljcdn.com/feroot/pc/asset/common.css?_v=201809070048259" rel="stylesheet"/>
# <link href="https://s1.ljcdn.com/feroot/pc/asset/ershoufang/sellDetail/detailV3.css?_v=201809070048259" rel="stylesheet"/>
# <!--[if lt IE 9]><script type="text/javascript" src="https://s1.ljcdn.com/feroot/dep/common-require/html5.js?_v=201809070048259"></script><![endif]-->
# <script>
# function RESIZEIMG(b,k,l,m){var c=b.parentNode;var d=parseInt(c.offsetWidth)||k;var e=parseInt(c.offsetHeight)||l;var f=d/e;var g=b.naturalWidth||b.width;var h=b.naturalHeight||b.height;var i=g/h;var j="width";if(f<i){j="height";try{b.style["left"]="-"+parseInt(Math.abs((d-(g*e/h))/2))+"px"}catch(e){}}else if(m){try{b.style["top"]="-"+parseInt(Math.abs((e-(h*d/g))/2))+"px"}catch(e){}};b.style[j]="100%";};
# </script>
# <script>
# var _czc = _czc || [];
# _czc.push(["_setAccount", "1254525948"]);
# </script>
# <script type="text/javascript">
# var _smq = _smq || [];
# _smq.push(['_setAccount', '41331c2', new Date()]);
# _smq.push(['_setDomainName', 'lianjia.com']);
# _smq.push(['pageview']);
# (function() {
# var sm = document.createElement('script'); sm.type = 'text/javascript'; sm.async = true;
# sm.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdnmaster.com/sitemaster/collect.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sm, s);
# })();
# </script>
# </head><body><script>
# __STAT_LJ_CONF = {
#     params: {
#         ljweb_group: ['SEARCH','BIGDATA_PC'],
#         ljweb_id: '',
#         ljweb_mod: '',
#         ljweb_bl: '',
#         ljweb_el: '',
#         ljweb_sl: '',
#         ljweb_index: '',
#         ljweb_value: '',
#         ljweb_url: '',
#         ljweb_ljref: (document.cookie.match(/(?:^| )ljref=([^;]*)(?:;|$)/) || ['',''])[1],
#         ljweb_sample: (document.cookie.match(/(?:^| )sample_traffic_test=([^;]*)(?:;|$)/) || ['',''])[1],
#         ljweb_ref: document.referrer,
#         ljweb_cid: '420100',
#         ljweb_channel: 'ershoufang',
#         ljweb_page: 'ershoufang_view',
#         ljweb_source: '',
#         ljweb_stat_id: ''
#     }
# };
#
#
#
# var UT = {
#     send: function() {
#
#     }
# };
# var LjUserTrack = {
#     log: [],
#     initInterval: false,
#     intervalLog: function() {
#         setTimeout(function() {
#             if(window.$ULOG && $ULOG.send) {
#                 for(var i = 0, l = LjUserTrack.log.length; i < l; i++) {
#                     LjUserTrack.__send(LjUserTrack.log[i]);
#                 }
#
#                 for(var m = 0, n = LjUserTrack.logIds.length; m < n; m++) {
#                     LjUserTrack.__sendId(LjUserTrack.logIds[m]);
#                 }
#                 for(var j = 0, k = LjUserTrack.logDatas.length; j < k; j++) {
#                     LjUserTrack.__sendData(LjUserTrack.logDatas[j].id, LjUserTrack.logDatas[j].data);
#                 }
#             } else {
#                 LjUserTrack.intervalLog();
#             }
#         }, 16.7);
#     },
#     _start_time: +new Date,
#     logDatas: [],
#     __sendData: function(id, data) {
#         if(id && (typeof(data) == 'object')){
#           data.pid = (window.__UDL_CONFIG && window.__UDL_CONFIG.pid && window.__UDL_CONFIG.pid)||"lianjiaweb";
#           data.key = window.location.href;
#           window.$ULOG && $ULOG.send(id, data);
#         }
#     },
#     sendData: function(id, data) {
#         if(window.$ULOG && $ULOG.send) {
#             LjUserTrack.__sendData(id, data);
#         } else {
#             LjUserTrack.logDatas.push({id: id, data: data});
#
#             LjUserTrack.initInterval || (LjUserTrack.initInterval = true, LjUserTrack.intervalLog());
#
#         }
#     },
#     __send: function(data) {
#         var evt_id = data.evt_id || '10043';
#         if('evt_id' in data) {
#             delete data.evt_id;
#         }
#
#         window.$ULOG && $ULOG.send(evt_id, {
#             "pid": (window.__UDL_CONFIG && window.__UDL_CONFIG.pid && window.__UDL_CONFIG.pid)||"lianjiaweb",
#             "key": window.location.href,
#             "action": data
#         });
#     },
#     logIds: [],
#     __sendId: function(id) {
#         id && window.$ULOG && window.$ULOG && $ULOG.send(id, {
#             "pid": (window.__UDL_CONFIG && window.__UDL_CONFIG.pid && window.__UDL_CONFIG.pid)||"lianjiaweb",
#             "key": window.location.href
#         });
#     },
#     sendId: function(id) {
#         if(window.$ULOG && $ULOG.send) {
#             LjUserTrack.__sendId(id);
#         } else {
#             LjUserTrack.logIds.push(id);
#
#             LjUserTrack.initInterval || (LjUserTrack.initInterval = true, LjUserTrack.intervalLog());
#
#         }
#     },
#     send: function(data, el, config) {
#
#         var utConf = __STAT_LJ_CONF;
#         var params = config || utConf.params,
#             win = window,
#             j;
#
#         data.groupIndex = data.ljweb_group || 0;
#
#         if (params) {
#             for (var d in params) {
#                 if(params[d] !== j && data[d] === j) {
#                     data[d] = params[d];
#                 }
#             }
#         }
#
#         if(el) {
#             this.checkClick(el, data);
#         }
#
#         data.ljweb_group = params['ljweb_group'][data.groupIndex || 0];
#
#         delete data.groupIndex;
#
#         if(data.typ) {
#             data.ljweb_bl = (data.ljweb_bl || '') + '_' + data.typ;
#             delete data.typ;
#         }
#
#         if(window.$ULOG && $ULOG.send) {
#             LjUserTrack.__send(data);
#         } else {
#             LjUserTrack.log.push(data);
#
#             LjUserTrack.initInterval || (LjUserTrack.initInterval = true, LjUserTrack.intervalLog());
#
#         }
#
#     },
#     checkClick: function(el, data) {
#
#         var TAG_LINK = 'A';
#         var href = '';
#         var elParent = null;
#
#         href = (el.tagName.toUpperCase() === TAG_LINK ? el.getAttribute("href", 2) : '');
#         if(!href && (elParent = el.parentNode) && elParent.nodeType === 1) {
#             href = (elParent.tagName.toUpperCase() === TAG_LINK ? elParent.getAttribute("href", 2) : '');
#         }
#
#         if(href) {
#             data.ljweb_url = href;
#         } else {
#             data.ljweb_url = data.ljweb_url
#                   || el.getAttribute("data-log_url")
#                   || (elParent=el.parentNode||el).getAttribute("data-log_url")
#                   || (
#                         (elParent=elParent.parentNode||elParent)
#                      && (elParent.nodeType === 1)
#                      && elParent.getAttribute("data-log_url")
#                      )
#                   || "";
#         }
#
#         this.attr(el, data);
#
#     },
#     path: function() {
#
#     },
#     attr: function(el, data) {
#         var modId     = el.getAttribute("log-mod");
#         var blAttr    = el.getAttribute("data-bl");
#         var elAttr    = el.getAttribute("data-el");
#         var slAttr    = el.getAttribute("data-sl");
#         var InAttr    = el.getAttribute("data-log_index");
#         var valAttr   = el.getAttribute("data-log_value");
#         var idAttr    = el.getAttribute("data-log_id");
#         var groupAttr = el.getAttribute("data-log_group");
#         var sourceAttr = el.getAttribute("data-log_source");
#         var statIdAttr = el.getAttribute("data-log_statId");
#         var evtId     = el.getAttribute("data-log_evtid");
#
#         data.ljweb_bl    = data.ljweb_bl || blAttr || '';
#         data.ljweb_el    = data.ljweb_el || elAttr || '';
#         data.ljweb_sl    = data.ljweb_sl || slAttr || '';
#         data.ljweb_index = data.ljweb_index || InAttr || '';
#         data.ljweb_value = data.ljweb_value || valAttr || '';
#         data.ljweb_id    = data.ljweb_id || idAttr || '';
#         data.ljweb_source    = data.ljweb_source || sourceAttr || '';
#         data.ljweb_stat_id    = data.ljweb_stat_id || statIdAttr || 0;
#         data.groupIndex  = data.groupIndex || groupAttr || 0;
#         data.evt_id      = data.evt_id || evtId || '';
#
#         if (!modId) {
#             if (el.parentNode && el.parentNode.nodeType === 1 && el.parentNode.tagName.toUpperCase() !== 'BODY') {
#                 this.attr(el.parentNode, data);
#             }
#         } else {
#             data.ljweb_mod = modId;
#         }
#     }
# };
#
# ;;(function() {
#     var isW3c = !!document.addEventListener;
#
#     LjUserTrack.send({
#         ljweb_mod: 'pv',
#         ljweb_group: 1
#     });
#
#     /*window[isW3c ? 'addEventListener' : 'attachEvent'](
#         (isW3c ? '': 'on') + 'beforeunload',
#         function(e) {
#             var _end_time = +new Date;
#             UT.send({type: 'show', subtype: 'stay', time: (_end_time-UT._start_time)/1000});
#         },
#         false);*/
# })();
#
#
#
#
#
# </script>
# <div class="banner"><div class="container"><ul class="channelList"><li><a href="//www.lianjia.com/">首页</a></li><li class="selected"><a href="https://wh.lianjia.com/ershoufang/">二手房</a></li><li class=""><a href="https://wh.fang.lianjia.com/">新房</a></li><li class=""><a href="https://wh.lianjia.com/zufang/">租房</a></li><li class="" rel="nofollow"><a href="http://you.lianjia.com/">旅居</a></li><li class=""><a href="https://us.lianjia.com">海外</a></li><li class=""><a href="https://wh.lianjia.com/xiaoqu/">小区</a></li><li class=""><a href="https://wh.lianjia.com/jingjiren/">经纪人</a></li><li class=""><a href="https://news.lianjia.com/wh/baike/">百科</a></li><li class=""><a href="https://wh.lianjia.com/fangjia/">房价</a></li><li class=""><a href="https://wh.lianjia.com/tool.html" target="_blank">工具</a></li><li class=""><a href="https://wh.lianjia.com/yezhu/" target="_blank">发布房源</a></li></ul><div class="banner-right"><div class="login" id="userInfoContainer"><i></i><a href="https://upassport.lianjia.com/login?service=https%3A%2F%2Fwww.lianjia.com%2Fuser%2Fchecklogin%3Fredirect%3Dhttps%253A%252F%252Fwh.lianjia.com%252Fershoufang%252F104101085322.html" id="loginBtn" rel="nofollow">登录</a>/<a href="https://passport.lianjia.com/register/resources/lianjia/register.html?service=https%3A%2F%2Fwww.lianjia.com%2Fuser%2Fchecklogin%3Fredirect%3Dhttps%253A%252F%252Fwh.lianjia.com%252Fershoufang%252F104101085322.html" id="registerBtn" rel="nofollow">注册</a></div><div class="phone"><i></i><span>热线电话1010-9666</span></div></div></div></div>
# <script id="userInfoTpl" type="text/template">
#   <i></i>
#   <%if(isAgent){%>
#     <a id="userNameContainer" href="<%=$.env.fixedUrl('//agent.lianjia.com/')%>"><%=username%></a>
#   <%}else{%>
#     <a id="userNameContainer" href="<%=$.env.fixedUrl('//user.lianjia.com/')%>" rel="nofollow"><%=username%></a>
#   <%}%>
#   <span id="tipContainer"></span>
#   &nbsp;&nbsp;<a href="<%=logoutUrl%>">退出</a>
#   <span id="pushNewsListContainer"></span>
# </script>
# <script id="pushNewsListTpl" type="text/template">
#   <div class="pushNewsList">
#     <%for(var i in group_by_type){%>
#       <%if(group_by_type[i].unread !== 0 && pushMsgMap.hasOwnProperty(i)){%>
#         <a href="<%=pushMsgMap[i].url%>"><%=$.replaceTpl(pushMsgMap[i].text, {unread:group_by_type[i].unread})%></a>
#       <%}%>
#     <%}%>
#   </div>
# </script>
# <div class="header"><div class="menu clear"><div class="menuLeft"><a class="logo" href="/ershoufang/"></a><!-- <span class="channelName">二手房</span> --><ul class="typeList"><li class="selected"><a href="/ershoufang/">在售</a></li><li><a href="/chengjiao/">成交</a></li><li><a href="/xiaoqu/">小区</a></li><li><a href="/fangjia/">房价</a></li><li><a href="/ditu/">地图找房</a></li></ul></div><div class="search"><div class="input" log-mod="search"><form action="/ershoufang/rs" id="searchForm"><span class="downArrow" data-bl="switch"><span class="state">在售</span><i></i></span><span class="sstate" data-bl="switch"><span data-state="1">在售</span><span data-state="2">成交</span><span data-state="3">小区</span></span><input autocomplete="off" id="searchInput" placeholder="请输入关键字搜索" type="text"/><button class="searchButton" data-bl="search" data-el="search" type="submit"> <i></i> </button></form><div class="searchMsg" id="searchMsgContainer"></div></div></div></div></div>
# <script id="searchSuggestionTpl" type="text/template">
#   <div class="searchMsgTitle">
#     <span class="searchMsgName">你可能在找</span>
#   </div>
#   <ul data-bl="sug" data-el="sug">
#   <%for(var i = 0;i < list.length;i++){%>
#     <li>
#       <a href="<%=list[i].url%>" role="addHistory" data-log_index="<%=i+1%>" data-log_value="<%=list[i].title%>">
#         <span class="msgListTitle">
#           <%=list[i].title%>
#           <%if(list[i].region){%>
#             <span class="msgListArea"><%=list[i].region%></span>
#           <%}%>
#         </span>
#         <%if(type === 'sell'){%>
#           <span class="msgListAdd">约<%=list[i].count%>套在售</span>
#         <%}else if(type === 'deal'){%>
#           <span class="msgListAdd">约<%=list[i].count%>套成交</span>
#         <%}%>
#       </a>
#     </li>
#   <%}%>
#   </ul>
# </script>
# <div class="sellDetailHeader">
# <div class="title-wrapper" log-mod="detail_header">
# <div class="content">
# <div class="title">
# <h1 class="main" title="高层观景房 可望江 中间位置 安静不临街">高层观景房 可望江 中间位置 安静不临街</h1>
# <div class="sub" title="客厅带阳台 视野开阔 采光好 高层望江房 配套齐全 交通便利">客厅带阳台 视野开阔 采光好 高层望江房 配套齐全 交通便利</div>
# </div>
# <div class="btnContainer LOGVIEWDATA LOGVIEW" data-lj_action_housedel_id="3711056496921" data-lj_action_resblock_id="104101085322" data-lj_view_evtid="11227">
# <div>
# <div class="action">
# <button class="followbtn" id="follow">关注房源</button>
# <span class="count" id="favCount">43</span>人关注
#               <span class="layer-qrcode followLayer" style="display: none;">
# <span class="icon-qrcode">
# <img alt="下载链家app" height="100" src="//ajax.api.lianjia.com/qr/getDownloadQr?location=follow_app&amp;jweb_channel_key=ershoufang_view" width="100"/>
# </span>
# <span class="txt">下载链家APP</span>
# <span class="sub-txt">房源动态早知道</span>
# <span class="icon-close"></span>
# </span>
# </div>
# <div class="action ">
# <button class="add-to-cart" data-lj_dianji="10046" id="addToCart">预约看房</button>
# <button class="move-from-cart hide" data-lj_dianji="10048">已加入待看</button>
# <span class="count" id="cartCount">11</span>人看过
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="intro clear" mod-id="lj-common-bread"><div class="container"><div class="fl l-txt"><a href="/">链家网武汉站</a><span class="stp"> &gt; </span><a href="/ershoufang/">武汉二手房</a><span class="stp"> &gt; </span><a href="/ershoufang/jiangan/">江岸二手房</a><span class="stp"> &gt; </span><a href="/ershoufang/baibuting/">百步亭二手房</a><span class="stp"> &gt; </span><a href="/ershoufang/c3711056496921/">银泰御华园一期二手房</a><span class="stp"> &gt; </span> <span>当前房源</span> </div></div></div>
# <div class="overview"><div class="img" id="topImg"><div class="imgContainer"><img alt="" class="new-default-icon maxWidth defaultImg" data-video="false" src="https://s1.ljcdn.com/feroot/pc/asset/img/blank.gif?_v=201809070048259"/><span></span></div><div class="thumbnail" id="thumbnail2"><div class="pre">&lt;</div><ul class="smallpic"><li data-desc="客厅" data-pic="https://image1.ljcdn.com/420100-inspection/test-e2a57ac0-b4c4-4a19-b913-414cb21a48de.png.1420x800.jpg" data-size="1420x800" data-src="https://image1.ljcdn.com/420100-inspection/test-e2a57ac0-b4c4-4a19-b913-414cb21a48de.png.710x400.jpg"><img alt="" src="https://image1.ljcdn.com/420100-inspection/test-e2a57ac0-b4c4-4a19-b913-414cb21a48de.png.120x80.jpg"/></li><li data-desc="客厅" data-pic="https://image1.ljcdn.com/420100-inspection/test-c60fffa0-dda8-4afd-9fa2-678f9570cc51.png.1420x800.jpg" data-size="1420x800" data-src="https://image1.ljcdn.com/420100-inspection/test-c60fffa0-dda8-4afd-9fa2-678f9570cc51.png.710x400.jpg"><img alt="" src="https://image1.ljcdn.com/420100-inspection/test-c60fffa0-dda8-4afd-9fa2-678f9570cc51.png.120x80.jpg"/></li><li data-desc="餐厅" data-pic="https://image1.ljcdn.com/420100-inspection/test-0f727b73-ab60-4410-9c36-c90fcdedbb79.png.1420x800.jpg" data-size="1420x800" data-src="https://image1.ljcdn.com/420100-inspection/test-0f727b73-ab60-4410-9c36-c90fcdedbb79.png.710x400.jpg"><img alt="" src="https://image1.ljcdn.com/420100-inspection/test-0f727b73-ab60-4410-9c36-c90fcdedbb79.png.120x80.jpg"/></li><li data-desc="户型图" data-pic="https://image1.ljcdn.com/x-se/hdic-frame/test-8d414951-6ccf-400d-a5f9-55023295195e.png.1066x800.jpg" data-size="1066x800" data-src="https://image1.ljcdn.com/x-se/hdic-frame/test-8d414951-6ccf-400d-a5f9-55023295195e.png.533x400.jpg"><img alt="" src="https://image1.ljcdn.com/x-se/hdic-frame/test-8d414951-6ccf-400d-a5f9-55023295195e.png.120x80.jpg"/></li><li data-desc="卧室A" data-pic="https://image1.ljcdn.com/420100-inspection/test-7b6feabd-8365-4836-b82a-30f1d75a5ec5.png.1420x800.jpg" data-size="1420x800" data-src="https://image1.ljcdn.com/420100-inspection/test-7b6feabd-8365-4836-b82a-30f1d75a5ec5.png.710x400.jpg"><img alt="" src="https://image1.ljcdn.com/420100-inspection/test-7b6feabd-8365-4836-b82a-30f1d75a5ec5.png.120x80.jpg"/></li><li data-desc="卧室B" data-pic="https://image1.ljcdn.com/420100-inspection/test-3ed4cb0b-ac94-473b-a590-68997ea388f9.png.1420x800.jpg" data-size="1420x800" data-src="https://image1.ljcdn.com/420100-inspection/test-3ed4cb0b-ac94-473b-a590-68997ea388f9.png.710x400.jpg"><img alt="" src="https://image1.ljcdn.com/420100-inspection/test-3ed4cb0b-ac94-473b-a590-68997ea388f9.png.120x80.jpg"/></li></ul><div class="next">&gt;</div></div></div><div class="content"><span class="sharethis"><i></i>分享此房源</span><div class="compareBtn LOGCLICK" data-bl="right_top" data-log_evtid="10231" log-mod="104101085322"><span class="compareIcon"></span><span class="compareText">加入对比</span></div><div class="price "><span class="total">159</span><span class="unit"><span>万</span></span><div class="text"><div class="unitPrice"><span class="unitPriceValue">21071<i>元/平米</i></span></div><div class="tax"><span class="taxtext" title="首付48万 税费"><span>首付48万 </span><span>税费</span><span><span id="PanelTax">13.8</span>万(仅供参考) </span></span><span class="detail" id="lookdetail">详情</span></div></div><div class="removeIcon"></div></div><div class="houseInfo"><div class="room"><div class="mainInfo">2室2厅</div><div class="subInfo">高楼层/共32层</div></div><div class="type"><div class="mainInfo" title="南">南</div><div class="subInfo">平层/简装</div></div><div class="area"><div class="mainInfo">75.46平米</div><div class="subInfo">2013年建/板楼</div></div></div><div class="aroundInfo"><div class="communityName"><i></i><span class="label">小区名称</span><a class="info " href="/xiaoqu/3711056496921/" target="_blank">银泰御华园一期</a><a class="map" href="#around">地图</a></div><div class="areaName"><i></i><span class="label">所在区域</span><span class="info"><a href="/ershoufang/ji ...
# <div class="tab-wrap">
# <div class="wrap">
# <div class="panel-tab">
# <ul class="clear">
# <li>
# <a class="on" href="#introduction">房源信息介绍</a>
# </li>
# <li>
# <a href="#layout">户型分间</a>
# </li>
# <li>
# <a href="#calculator" id="taxm">税费贷款</a>
# </li>
# <li>
# <a href="#record">看房记录</a>
# </li>
# <li>
# <a href="#resblockCardContainer">小区简介</a>
# </li>
# <li>
# <a href="#dealPrice">小区成交</a>
# </li>
# <li>
# <a class="LOGCLICK" data-bl="supporting" data-log_evtid="10242" href="#around">周边配套</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="m-content">
# <div class="box-l">
# <!-- 基本信息 -->
# <div class="newwrap baseinform" id="introduction">
# <div class="" style="width:700px;">
# <h2><div class="title">基本信息</div></h2>
# <div class="introContent">
# <div class="base">
# <div class="name">基本属性</div>
# <div class="content">
# <ul>
# <li><span class="label">房屋户型</span>2室2厅1厨1卫</li>
# <li><span class="label">所在楼层</span>高楼层 (共32层)</li>
# <li><span class="label">建筑面积</span>75.46㎡</li>
# <li><span class="label">户型结构</span>平层</li>
# <li><span class="label">套内面积</span>暂无数据</li>
# <li><span class="label">建筑类型</span>板楼</li>
# <li><span class="label">房屋朝向</span>南</li>
# <li><span class="label">建筑结构</span>钢混结构</li>
# <li><span class="label">装修情况</span>简装</li>
# <li><span class="label">梯户比例</span>两梯六户</li>
# <li><span class="label">配备电梯</span>有</li>
# <li><span class="label">产权年限</span>70年</li>
# </ul>
# </div>
# </div>
# <div class="transaction">
# <div class="name">交易属性</div>
# <div class="content">
# <ul>
# <li>
# <span class="label">挂牌时间</span>
# <span>2018-07-04</span>
# </li>
# <li>
# <span class="label">交易权属</span>
# <span>商品房</span>
# </li>
# <li>
# <span class="label">上次交易</span>
# <span>暂无数据</span>
# </li>
# <li>
# <span class="label">房屋用途</span>
# <span>普通住宅</span>
# </li>
# <li>
# <span class="label">房屋年限</span>
# <span>暂无数据</span>
# </li>
# <li>
# <span class="label">产权所属</span>
# <span>非共有</span>
# </li>
# <li>
# <span class="label">抵押信息</span>
# <span style="display:inline-block;width:64%;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;vertical-align:middle;" title="无抵押">
#                                 无抵押
#                               </span>
# </li>
# <li>
# <span class="label">房本备件</span>
# <span>未上传房本照片</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="disclaimer" style="padding-top: 10px;">注：房源所示“房屋用途、交易权属、建成年代、产权年限、建筑结构”仅供参考，购房时请以房本信息为准。</div>
# </div>
# </div>
# </div>
# <!-- 房源特色 -->
# <div class="newwrap baseinform">
# <h2><div class="title" style="margin-top:50px;">房源特色</div></h2>
# <div class="introContent showbasemore">
# <div class="tags clear">
# <div class="name">房源标签</div>
# <div class="content">
# <a class="tag is_near_subway" href="https://wh.lianjia.com/ershoufang/baibuting/su1/">地铁</a>
# <a class="tag is_see_free" href="https://wh.lianjia.com/ershoufang/baibuting/tt4/">随时看房</a>
# </div>
# </div>
# <div class="baseattribute clear">
# <div class="name">小区介绍</div>
# <div class="content">
#                     开发商：银泰开发商开发，大开发商实力保障。   物业：嘉邦物业开发有限公司负责管理，拥有强劲的管理和服务品质，居住体验很好。   小区环境：封闭式管理，人车分流，地下停车，各门口24小时保安守护，小区内部环境安静优雅，相当宜居的次新小区。
#                   </div>
# </div>
# <div class="baseattribute clear">
# <div class="name">交通出行</div>
# <div class="content">
#                     距离地铁3号线兴业路站仅400米(数据来源于百度地图)，与地铁1号线、2号线、4号线、6号线、8号线、21号线共6条地铁线无缝对接换乘；有319、332、592、717多路公交车通往武汉三镇，小区西边从建设大道延长线开车能直达二环，路途仅1.5k
#                   </div>
# </div>
# <div class="baseattribute clear">
# <div class="name">核心卖点</div>
# <div class="content">
#                     客厅带阳台 视野开阔 采光好 高层望江房 配套齐全 交通便利
#                   </div>
# </div>
# <div class="viewmore">展开更多信息</div>
# <div class="disclaimer">注：土地使用起止年限详见业主土地证明材料或查询相关政府部门的登记文件。</div>
# </div>
# </div>
# <!-- 房主自荐 -->
# <div class="newwrap" id="daikanContainer" log-mod="ershoufang_detail_agent-daikan"></div>
# <script id="daikanTpl" type="text/template">
#   <%if(totalSeeRecordNum !== 0){%>
#     <div class="comment_daikan">
#       <div class="daikan_header clear">
#         <h3><div class="daikan_title fl">经纪人带看反馈</div></h3>
#         <div class="daikan_filter fr">
#           <span class="tag <%=order === 0 ? 'on' : 'LOGCLICK'%>" id="newestComment" data-bl="typ">最新</span>
#           <span class="tag <%=order === 1 ? 'on' : 'LOGCLICK'%>" id="usefulComment" data-bl="typ">最有用</span>
#         </div>
#       </div>
#       <div class="daikan_content">
#         <%for(var i = 0 ; i < agentList.length; i++){%>
#         <%if (agentList[i].agent_information_card === undefined || agentList[i].agent_information_card){%>
#           <div class="daikan_list">
#             <div class="item clear">
#               <a target="_blank" class="item_img fl <%=notFetch ? '': 'LOGVIEW'%> LOGCLICK" href="<%=agentList[i].url%>" data-log_id="20001" data-bl="agent" data-el="<%=agentList[i].agentUcid%>" data-log_index="<%=i+1%>">
#                 <%if(agentList[i].photo){%>
#                   <img src="<%=agentList[i].photo%>.55x55.jpg" alt="">
#                 <%}else{%>
#                   <img src="<%=defaultImg%>" alt="">
#                 <%}%>
#               </a>
#               <!-- 这里 -->
#               <div class="daikan_item_content fr clear">
#                 <div class="fl">
#                   <div class="item_title">
#                     <a target="_blank" class="itemAgentName LOGCLICK" href="<%=agentList[i].url%>" data-log_id="20001" data-bl="agent" data-el="<%=agentList[i].agentUcid%>" data-log_index="<%=i+1%>"><%=agentList[i].name%></a>
#                     <%if (agentList[i].agent_information_card){%>
#                     <div class="agentCredentials agent_information_card" data-card_info="<%=agentList[i].agent_information_card%>"></div>
#                     <%}%>
#                     <!-- <%if(agentList[i].appid == '104') {%>
#                       <div class="dy no_f"><span class="dy_tag lj_tag" style="display:none">链家</span></div>
#                       <%}else if(agentList[i].appid == '105') {%>
#                        <div class="dy no_f"><span class="dy_tag" style="color:#9399a5 !important;background-color:#eff0f2">德佑</span><i class="xiaowenhao"></i><b class="dy_desc">德佑地产是链家集团旗下品牌，致力于为消费者提供个性化的房产服务。</b></div>
#                        <%}else if(agentList[i].appid == '202') {%>
#                        <div class="dy no_f"><span class="dy_tag" style="color:#9399a5 !important;background-color:#eff0f2">美家</span></div>
#                       <%}%> -->
#                       <%if(agentList[i].appid !== '104') {%>
#                           <div class="dy no_f">
#                               <span class="dy_tag" style="color:#9399a5 !important;background-color:#eff0f2"><%=agentList[i].company_name%></span>
#                               <%if(agentList[i].appid === '105') {%>
#                                   <i class="xiaowenhao"></i><b class="dy_desc">德佑地产是链家集团旗下品牌，致力于为消费者提供个性化的房产服务。</b>
#                               <%}%>
#                           </div>
#                       <%}%>
#                     <span class="phone"><%=agentList[i].phone%></span>
#                   </div>
#                   <div class="des"><%=agentList[i].comment === '' ? '该经纪人还未提交相关评论反馈' : agentList[i].comment%></div>
#                   <div class="daikan_item_record"><%=agentList[i].lastestSeeRecordDate%>带客户看过此房，共带看本房<%=agentList[i].agentSeeRecordNum%>次</div>
#                 </div>
#                 <%
#                   var userableStyle = '';
#                   if(parseInt(agentList[i].isCurrentUserUseful, 10) === 1){
#                     userableStyle = 'on';
#                   }else if(agentList[i].comment === ''){
#                     userableStyle = 'none';
#                   }
#                 %>
#
#                   <%if(agentList[i].isValid){%>
#                     <span class="agent_chat im-talk fr LOGCLICK LOGCLICKDATA" data-ucid="<%=agentList[i].agentUcid%>" data-log_id="20001" data-bl="agentim" data-el="<%=agentList[i].agentUcid%>" data-log_index="<%=i+1%>" data-source-port="PC:ershou_ershoufang_comments" data-lj_evtid="11048" data-lj_action_type="Display_Tour" data-lj_action_resblock_id="<%=resblockId%>" data-lj_action_housedel_id="<%=houseCode%>" data-lj_action_ucid="<%=agentList[i].agentUcid%>" data-source-extends=<%=JSON.stringify(newHouseCode)%> >
#                       <i></i>
#                       <span>咨询</span>
#                     </span>
#                   <%}%>
#                 <div class="item_useable_btn fr <%=userableStyle%>" data-index="<%=i%>">
#                   <i data-index="<%=i%>"></i>
#                   <span data-index="<%=i%>">
#                     <%=isChangingIndex === i ? '请求中' : '有用'%><%if(agentList[i].totalUsefulNum != 0){%>(<%=agentList[i].totalUsefulNum%>)<%}%>
#                   </span>
#                 </div>
#
#               </div>
#             </div>
#           </div>
#         <%}%>
#         <%}%>
#         <div class="daikanPager clear">
#           <div class="fr">
#             <%=currentPage%>/<%=totalPageNum%>
#             <div class="daikanPagerBtn daikan_left_arrow <%if(currentPage === 1){%>disable<%}else{%>LOGCLICK<%}%>" id="prePageComment" data-bl="switch"><span><</span></div>
#             <div class="daikanPagerBtn daikan_right_arrow <%if(currentPage === parseInt(totalPageNum, 10)){%>disable<%}else{%>LOGCLICK<%}%>" id="nextPageComment" data-bl="switch"><span>></span></div>
#           </div>
#         </div>
#         <div class="daikan_content_loading" <%=isFetching ? 'style="display:block;"' : ''%> ></div>
#       </div>
#     </div>
#   <%}%>
# </script>
# <!-- 户型分间 -->
# <div class="newwrap">
# <div class="layout-wrapper" id="layout">
# <div class="layout">
# <h3><div class="title">户型分间</div></h3>
# <div class="frame frameItem">
# <!-- -->
# <div class="agent-tips">
# <div class="fr">
# <div>
# <a class="name" href="https://dianpu.lianjia.com/1000000020057811" target="_blank">袁文芳</a>
# <span class="tag">/房源维护人</span>
# <a class="lianjiaim-createtalkAll im-talk new-talk LOGCLICKDATA" data-lj_action_housedel_id="104101085322" data-lj_action_resblock_id="3711056496921" data-lj_action_type="Display_Housetype" data-lj_action_ucid="1000000020057811" data-lj_evtid="11048" data-source-extends='{"house_code":"104101085322"}' data-source-port="PC:ershou_ershoufang_huxingzhuanjia" data-ucid="1000000020057811" style="display: none;" title="在线咨询">
# <span class="im-icon"></span>
# </a>
# </div>
# <p>4008956286转9006</p>
# </div>
# <div class="fl">
# <a class="name" href="https://dianpu.lianjia.com/1000000020057811" target="_blank">
# <img alt="袁文芳" class="agent-icon" src="https://image1.ljcdn.com/usercenter/images/uc_ehr_avatar/37415020-b144-41ad-9227-a41b1d31102e.jpg.40x40.jpg"/>
# </a>
# </div>
# </div>
# </div>
# <div class="content">
# <div class="clear"></div>
# <div class="imgdiv" data-img="https://image1.ljcdn.com/x-se/hdic-frame/test-8d414951-6ccf-400d-a5f9-55023295195e.png">
# <img alt="高层观景房 可望江 中间位置 安静不临街户型图" src="https://image1.ljcdn.com/x-se/hdic-frame/test-8d414951-6ccf-400d-a5f9-55023295195e.png.240x180.jpg"/>
# <span class="setbig">
# <i></i>
# <label>查看原图</label>
# </span>
# </div>
# <div class="des">
# <div class="info">
# <div class="list">
# <div id="infoList">
# <div class="row">
# <div class="col">客厅</div>
# <div class="col">13.56平米</div>
# <div class="col">南</div>
# <div class="col">落地窗</div>
# </div>
# <div class="row">
# <div class="col">餐厅</div>
# <div class="col">9.74平米</div>
# <div class="col">无</div>
# <div class="col">无窗</div>
# </div>
# <div class="row">
# <div class="col">卧室A</div>
# <div class="col">6.25平米</div>
# <div class="col">南</div>
# <div class="col">普通窗</div>
# </div>
# <div class="row">
# <div class="col">卧室B</div>
# <div class="col">12.16平米</div>
# <div class="col">无</div>
# <div class="col">未知窗户类型</div>
# </div>
# <div class="row">
# <div class="col">厨房</div>
# <div class="col">4.81平米</div>
# <div class="col">南</div>
# <div class="col">普通窗</div>
# </div>
# <div class="row">
# <div class="col">卫生间</div>
# <div class="col">3.27平米</div>
# <div class="col">无</div>
# <div class="col">普通窗</div>
# </div>
# <div class="row">
# <div class="col">阳台</div>
# <div class="col">4.3平米</div>
# <div class="col">南</div>
# <div class="col">落地窗</div>
# </div>
# <div class="row">
# <div class="col">阳台A</div>
# <div class="col">3.08平米</div>
# <div class="col">南</div>
# <div class="col">普通窗</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <span class="justify_fix"></span>
# <p class="disclaimer">注：户型图标注的面积不同于房本面积，存在测量误差，购房请以房本面积为准。</p>
# </div>
# </div>
# </div>
# </div>
# <!-- 房源照片 -->
# <div class="newwrap">
# <div class="content-wrapper housePic">
# <h3><div class="title">房源照片</div></h3>
# <div class="container">
# <div class="list">
# <div data-index="0">
# <img alt="客厅" src="https://image1.ljcdn.com/420100-inspection/test-e2a57ac0-b4c4-4a19-b913-414cb21a48de.png.710x400.jpg"/>
# <span class="name">客厅</span>
# </div>
# <div data-index="1">
# <img alt="客厅" src="https://image1.ljcdn.com/420100-inspection/test-c60fffa0-dda8-4afd-9fa2-678f9570cc51.png.710x400.jpg"/>
# <span class="name">客厅</span>
# </div>
# <div data-index="2">
# <img alt="餐厅" src="https://image1.ljcdn.com/420100-inspection/test-0f727b73-ab60-4410-9c36-c90fcdedbb79.png.710x400.jpg"/>
# <span class="name">餐厅</span>
# </div>
# <div data-index="3">
# <img alt="户型图" src="https://image1.ljcdn.com/x-se/hdic-frame/test-8d414951-6ccf-400d-a5f9-55023295195e.png.533x400.jpg"/>
# <span class="name">户型图</span>
# </div>
# <div data-index="4">
# <img alt="卧室A" src="https://image1.ljcdn.com/420100-inspection/test-7b6feabd-8365-4836-b82a-30f1d75a5ec5.png.710x400.jpg"/>
# <span class="name">卧室A</span>
# </div>
# <div data-index="5">
# <img alt="卧室B" src="https://image1.ljcdn.com/420100-inspection/test-3ed4cb0b-ac94-473b-a590-68997ea388f9.png.710x400.jpg"/>
# <span class="name">卧室B</span>
# </div>
# <!-- <div>
#                   <img src="//placehold.it/450x338" alt="">
#                   <span class="name">客厅A 18平米 南 落地窗</span>
#                 </div> -->
# <div class="left_fix"></div><div class="left_fix"></div></div>
# </div>
# <div class="more">查看更多图片</div>
# </div>
# </div>
# <!-- 对口学校 -->
# <!-- 税费计算器、房贷计算器 -->
# <div class="newwrap">
# <div class="calculator" id="calculator">
# <div class="cal-title" id="calculatorTab">
# <div class="tax-tab select" data-target="#taxCalculator">
# <h3 class="title">税费计算器</h3>
# </div>
# <div class="loan-tab title" data-target="#loanCalculator">房贷计算器</div>
# <p class="calculatorTabpropmt">税费、房贷信息仅供参考，具体金额请以实际发生为准。</p>
# </div>
# <div class="tax" id="taxCalculator">
# <div class="option">
# <div class="row">
# <label for="">住宅类型：</label>
# <div class="content select-content">
# <span class="itemName">普通住宅</span>
# <span class="arrow"></span>
# <ul>
# <li>普通住宅</li>
# <li>非普通住宅</li>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">卖房家庭唯一：</label>
# <div class="content select-content">
# <span class="itemName">唯一</span>
# <span class="arrow"></span>
# <ul>
# <li>唯一</li>
# <li>不唯一</li>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">距上次交易：</label>
# <div class="content select-content">
# <span class="itemName">满五年</span>
# <span class="arrow"></span>
# <ul>
# <li>满五年</li>
# <li>满两年</li>
# <li>不满两年</li>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">买房家庭首套：</label>
# <div class="content select-content">
# <span class="itemName">首套</span>
# <span class="arrow"></span>
# <ul>
# <li>首套</li>
# <li>二套</li>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">计征方式：</label>
# <div class="content select-content">
# <span class="itemName">总价</span>
# <span class="arrow"></span>
# <ul>
# <li>总价</li>
# <li>差价</li>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">房屋面积：</label>
# <div class="content bord"><input type="text"/><span class="unit">平方米</span></div>
# </div>
# <div class="row">
# <label for="">房屋总价：</label>
# <div class="content bord"><input type="text"/><span class="unit">万元</span></div>
# </div>
# <div class="row" style="display:none;">
# <label for="">买卖差价：</label>
# <div class="content bord"><input type="text"/><span class="unit">万元</span></div>
# </div>
# <div class="row btn"><button>开始计算</button></div>
# </div>
# <div class="tax-right">
# <div class="result">
# <div class="total">
# <span class="name">合计</span>
# <span class="value" id="totalTax">2545452.71</span>
# <span class="unit">元</span>
# </div>
# <div class="item">
# <span class="name">契税：</span>
# <span class="value" id="deedTax">132451</span>
# <span class="unit">元</span>
# </div>
# <div class="item">
# <span class="name">增值税：</span>
# <span class="value" id="businessTax">132451</span>
# <span class="unit">元</span>
# </div>
# <div class="item">
# <span class="name">个税：</span>
# <span class="value" id="incomeTax">132451</span>
# <span class="unit">元</span>
# </div>
# </div>
# <div class="pie" id="taxPie"></div>
# </div>
# </div>
# <div class="loan" id="loanCalculator">
# <div class="option">
# <div class="row">
# <label for="">贷款类型：</label>
# <div class="content select-content">
# <span class="itemName"></span>
# <span class="arrow"></span>
# <ul>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">贷款金额：</label>
# <div class="content select select-content">
# <span class="itemName"></span>
# <span class="arrow"></span>
# <ul>
# </ul>
# </div>
# <div class="input bord">
# <input class="mixInput" type="text"/>
# <span>万元</span>
# </div>
# </div>
# <div class="row">
# <label for="">贷款期限：</label>
# <div class="content select-content">
# <span class="itemName"></span>
# <span class="arrow"></span>
# <ul>
# </ul>
# </div>
# </div>
# <div class="row">
# <label for="">商贷年利率：</label>
# <div class="content select select-content">
# <span class="itemName"></span>
# <span class="arrow"></span>
# <ul>
# </ul>
# </div>
# <div class="input bord">
# <input class="mixInput" type="text"/>
# <span>%</span>
# </div>
# </div>
# <div class="row">
# <label for="">公积金利率：</label>
# <div class="content select select-content">
# <span class="itemName"></span>
# <span class="arrow"></span>
# <ul>
# </ul>
# </div>
# <div class="input">
# <input class="mixInput" type="text"/>
# <span>%</span>
# </div>
# </div>
# <div class="row">
# <label for="">商业贷款金额：</label>
# <div class="content"><input type="text"/><span class="unit">万元</span></div>
# </div>
# <div class="row">
# <label for="">公积金贷款金额：</label>
# <div class="content"><input type="text"/><span class="unit">万元</span></div>
# </div>
# <div class="row btn"><button>开始计算</button></div>
# </div>
# <div class="loan-right">
# <div class="sm-title" id="sm-title">
# <span class="fl sm-select" data-target="#interestbox">等额本息还款</span>
# <span class="fr" data-target="#capitalbox">等额本金还款</span>
# </div>
# <div class="interest" id="interestbox">
# <div class="item">
# <span class="name">月供：</span>
# <span class="value repayment" id=""></span>
# <span class="unit">元</span>
# <div class="des"></div>
# </div>
# <div class="item">
# <span class="name">还款月数：</span>
# <span class="value monthNum" id="">360</span>
# <span class="unit">月</span>
# </div>
# <div class="item">
# <span class="name">总利息：</span>
# <span class="value totalInterest" id=""></span>
# <span class="unit">元</span>
# </div>
# <div class="item">
# <span class="name">本息合计：</span>
# <span class="value totalMoney" id=""></span>
# <span class="unit">元</span>
# </div>
# </div>
# <div class="capital" id="capitalbox">
# <div class="item">
# <span class="name">月供：</span>
# <span class="value repayment" id=""></span>
# <span class="unit">元</span>
# <div class="des"><div>首月后每月递减<span id="decrease">12.50</span>元</div></div>
# </div>
# <div class="item">
# <span class="name">还款月数：</span>
# <span class="value monthNum" id=""></span>
# <span class="unit">月</span>
# </div>
# <div class="item">
# <span class="name">总利息：</span>
# <span class="value totalInterest" id=""></span>
# <span class="unit">元</span>
# </div>
# <div class="item">
# <span class="name">本息合计：</span>
# <span class="value totalMoney" id=""></span>
# <span class="unit">元</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 看房记录 -->
# <div class="newwrap">
# <div class="record" id="record">
# <div class="list">
# <div class="title">看房记录
#                   <span class="next disable"><i></i></span>
# <span class="pre disable"><i></i></span>
# </div>
# <div class="content">
# <div class="record-header">
# <div class="item mytime">带看时间</div>
# <div class="item myname">带看经纪人</div>
# <div class="item mytotal">本房总带看</div>
# <div class="phone" style="margin-left:12px;">咨询电话</div>
# </div>
# <div class="row"><span class="noData">暂无看房记录</span></div>
# </div>
# </div>
# <div class="panel">
# <div class="panel-title">近7天带看次数</div>
# <div class="count">0</div>
# <div class="totalCount">- 30日带看<span>0</span>次 -</div>
# <!-- <div class="msyy">马上预约看房</div> -->
# </div>
# </div>
# </div>
# <!-- 价格变动 -->
# <div class="newwrap">
# <div class="priceChange">
# <div class="pchangeheader">
# <span class="title">价格变动</span>
# <span class="subTitle">当前房源共有过<span></span>条价格记录</span>
# <span class="btn">
# <span class="pre disable"><i></i></span>
# <span class="next disable"><i></i></span>
# </span>
# </div>
# <div class="container" id="priceChangeBar">
# <ul></ul>
# <!-- <div class="boxp blue">
#                 <div class="inin">
#                   <span class="pricename">挂牌价</span><br>
#                   <span class="pricevalue">2500万</span>
#                 </div>
#               </div>
#               <div class="boxp red"></div>
#               <div class="boxp green"></div> -->
# </div>
# </div>
# </div>
# <div id="resblockCardContainer"></div>
# <div id="resblockBannerContainer"></div>
# <!-- 小区成交价格 -->
# <div class="newwrap" id="dealPrice">
# <div class="dealPrice">
# <div class="priceheader">
# <div class="title">小区成交价格</div>
# <div class="des">
# <div class="from"><i></i>数据来源：成交系统数据统计</div>
# <div class="update"><i></i>更新日期：<span id="dealDataUpdateTime"></span></div>
# </div>
# </div>
# <div class="averagePriceContainer">
# <div class="averagePriceCharts" style="height: 300px;"></div>
# <ol class="averagePriceTabs">
# <li class="on" data-type="total">全部</li>
# <li data-type="1_bed">一居</li>
# <li data-type="2_bed">二居</li>
# <li data-type="3_bed">三居</li>
# <li data-type="other">其他</li>
# </ol>
# </div>
# </div>
# <!-- 同小区成交记录 -->
# <div class="dealRecord" style="margin-top:35px;">
# <div class="title">
# <span class="resblockDeal" data-target="#resblockDeal">同小区成交记录</span>
# <span class="bizcircleDeal" data-target="#bizcircleDeal">同商圈成交记录</span>
# </div>
# <div id="bizcircleDeal">
# </div>
# <div id="resblockDeal">
# <div class="noData">暂无成交记录</div>
# </div>
# </div>
# </div>
# </div>
# <div class="box-r">
# <div class="agbox">
# <div class="myAgent " log-mod="ershoufang_detail_diamond-many">
# <div class="topinfor clear">
# <span class="fl">联系经纪人</span>
# <span class="fr LOGCLICK" data-bl="switch" data-log_id="20001" id="changeAgentBtn"><span class="change"></span>换一换</span>
# </div>
# <div id="diamondAgent"></div>
# <div class="myfollow myfollowcss followbtn">关注房源</div>
# <div class="mycartcss add-to-cart" data-lj_dianji="10047">预约看房</div>
# <div class="mycartcss move-from-cart hide" data-lj_dianji="10049">已加入待看</div>
# <div class="compareFixBtn LOGCLICK" data-bl="right_bottom" data-log_evtid="10231" log-mod="104101085322">
# <span class="compareIcon"></span>
# <span class="compareText">加入对比</span>
# </div>
# <div class="myline"></div>
# <!-- <div class="looknum"><span id="haslook"></span></div> -->
# <!-- <div class="addyuyue">加入预约带看</div> -->
# </div>
# </div>
# </div>
# </div>
# <!-- 周边配套 -->
# <div class="around" id="around">
# <h2 class="aroundTitle">周边配套</h2>
# <div class="aroundContainer">
# <div class="aroundMap" id="map">
# </div>
# <div class="tabBox">
# <ul class="aroundType">
# <li class="LOGCLICK" data-bl="traffic" data-index="subway,bus" data-key="地铁站,公交站" data-length="10,10" data-log_evtid="10242">交通</li>
# <li class="LOGCLICK" data-bl="education" data-index="kindergarten,primary-school,middle-school,University" data-key="幼儿园,小学,中学,大学" data-length="10,10,10,10" data-log_evtid="10242">教育</li>
# <li class="LOGCLICK" data-bl="medical" data-index="hospital,pharmacy" data-key="医院,药店" data-length="10,10" data-log_evtid="10242">医疗</li>
# <li class="LOGCLICK" data-bl="shopping" data-index="mall,supermarket,market" data-key="商场,超市,市场" data-length="10,10,10" data-log_evtid="10242">购物</li>
# <li class="LOGCLICK" data-bl="life" data-index="bank,atm,restaurant,coffee" data-key="银行,ATM,餐厅,咖啡馆" data-length="10,10,10,10" data-log_evtid="10242">生活</li>
# <li class="LOGCLICK" data-bl="entertainment" data-index="park,cinema,gym,sport" data-key="公园,电影院,健身房,体育馆" data-length="10,10,10,10" data-log_evtid="10242">娱乐</li>
# </ul>
# <div class="itemTagBox"></div>
# <div class="aroundList" id="mapListContainer"></div>
# <div class="loading">
# <img class="loadingImg" src="https://s1.ljcdn.com/feroot/pc/asset/ershoufang/sellDetail/img/loading.gif?_v=201809070048259"/>
# <span class="loadingText">努力加载中...</span>
# </div>
# </div>
# </div>
# </div>
# <!-- <div class="agentCredentialsPop">
#   <div class="pop-close"></div>
#   <img src="http://image1.ljcdn.com/ehr-personnel/20180822155730058OYNNTWWY.jpg!m_original,lg_north_west,lx_0,ly_0,l_rorate_logo,f_jpg,ls_70" alt="">
# </div> -->
# <div class="LOGVIEWDATA" id="pushContainer" log-mod="ershoufang_detail_recommend-ershoufang"></div>
# <div id="pushXinfang"></div>
# <div class="promise">
# <div class="item zhen">
# <a href="//www.lianjia.com/zhuanti/index">
# <i></i>
# <div class="text">
# <div class="title">真实房源</div>
# <div class="sub">真房源 假一赔百元</div>
# </div>
# </a>
# </div>
# <div class="item jianguan">
# <a href="//nj.lianjia.com/baike/285.html">
# <i></i>
# <div class="text">
# <div class="title">交易资金监管</div>
# <div class="sub">保障交易安全</div>
# </div>
# </a>
# </div>
# <div class="item huigou">
# <a href="//www.lianjia.com/zhuanti/detail02">
# <i></i>
# <div class="text">
# <div class="title">最高原价回购</div>
# <div class="sub">辐射/凶宅</div>
# </div>
# </a>
# </div>
# <div class="item dianfu">
# <a href="//www.lianjia.com/zhuanti/detail04">
# <i></i>
# <div class="text">
# <div class="title">损失先行垫付</div>
# <div class="sub">物业欠费/签前查封</div>
# </div>
# </a>
# </div>
# <span class="justify_fix"></span>
# </div>
# <div class="m-yezhu"><div class="wrap"><div class="hd">我有房子要卖</div><ul><li class="item-gujia"><div class="marsk"></div><div class="tit">不知道如何定价</div><div class="sub-tit">每天超过30000次估价请求量</div><a class="btn-link" href="/yezhu/gujia/" target="_blank">我要估价 &gt;</a></li><li class="item-maifang"><div class="marsk"></div><div class="tit">把房源委托给链家</div><div class="sub-tit">10万+专业经纪人·8000+链家门店</div><a class="btn-link" href="/yezhu/maifang/" target="_blank">发布房源 &gt;</a></li><li class="item-xiazai"><div class="marsk"></div><div class="tit">已有房源在链家销售</div><div class="sub-tit">去链家APP业主中心管理委托</div><span class="btn-link btn-app" href="javascript:;"><span>去APP管理委托 &gt;</span><span class="layer-qrcode"><span class="icon-qrcode"></span><span class="txt">去链家APP提升卖房速度</span><span class="sub-txt">APP·移动卖房新体验</span></span></span></li></ul></div></div>
# <div class="layoutpicbg"></div>
# <div class="layoutpic">
# <img alt="" class="pic-img fl" src=""/> <span class="closepic">×</span>
# <div class="fr list">
# <div class="title">
# <b>户型分间</b>
# </div>
# <div class="lists">
# <ul id="layoutList">
# <li>
# <span class="col-1">客厅</span>
# <span class="col-2">13.56平米</span>
# <span class="col-3">南</span>
# <span class="col-4">落地窗</span>
# </li>
# <li>
# <span class="col-1">餐厅</span>
# <span class="col-2">9.74平米</span>
# <span class="col-3">无</span>
# <span class="col-4">无窗</span>
# </li>
# <li>
# <span class="col-1">卧室A</span>
# <span class="col-2">6.25平米</span>
# <span class="col-3">南</span>
# <span class="col-4">普通窗</span>
# </li>
# <li>
# <span class="col-1">卧室B</span>
# <span class="col-2">12.16平米</span>
# <span class="col-3">无</span>
# <span class="col-4">未知窗户类型</span>
# </li>
# <li>
# <span class="col-1">厨房</span>
# <span class="col-2">4.81平米</span>
# <span class="col-3">南</span>
# <span class="col-4">普通窗</span>
# </li>
# <li>
# <span class="col-1">卫生间</span>
# <span class="col-2">3.27平米</span>
# <span class="col-3">无</span>
# <span class="col-4">普通窗</span>
# </li>
# <li>
# <span class="col-1">阳台</span>
# <span class="col-2">4.3平米</span>
# <span class="col-3">南</span>
# <span class="col-4">落地窗</span>
# </li>
# <li>
# <span class="col-1">阳台A</span>
# <span class="col-2">3.08平米</span>
# <span class="col-3">南</span>
# <span class="col-4">普通窗</span>
# </li>
# </ul>
# </div>
# <!--       <div class="agent-tips">
#         <div class="fl">
#           <div>
#             <a class="name" href="https://dianpu.lianjia.com/1000000020057811" target="_blank">袁文芳</a><span class="tag">/户型顾问</span>
#             <a class="lianjiaim-createtalkAll new-talk" style="display: none;" title="在线咨询" data-ucid="1000000020057811">
#               <span class="im-icon"></span>
#             </a>
#           </div>
#             <p>4008956286转9006</p>
#         </div>
#         <div class="fr"><a class="name" href="https://dianpu.lianjia.com/1000000020057811" target="_blank"><img src="https://image1.ljcdn.com/usercenter/images/uc_ehr_avatar/37415020-b144-41ad-9227-a41b1d31102e.jpg.40x40.jpg" alt="袁文芳"></a></div>
#       </div>
#      -->
# </div>
# </div>
# <div class="bigImg">
# <div class="mask"></div>
# <div class="list">
# ...
#    window.__STAT_LJ_CONF.params.is_yanjiao=0;
#       </script>
# <script>
#   require(['ershoufang/sellDetail/detailV3'],function(init){
#     init({
#       ucid:'',
#       houseType:'普通住宅',
#       isUnique:'不唯一',
#       registerTime:'暂无数据',
#       area:'75.46',
#       totalPrice:'159',
#       price:'21071',
#       houseId:'104101085322',
#       resblockId:'3711056496921',
#       resblockName:'银泰御华园一期',
#       isRemove:'0',
#       defaultImg:'https://s1.ljcdn.com/feroot/pc/asset/img/blank.gif?_v=201809070048259',
#       defaultBrokerIcon:'https://s1.ljcdn.com/feroot/pc/asset/img/blank.gif?_v=201809070048259',
#       resblockPosition:'114.31576015386,30.644350332649',
#       cityId:'420100',
#       changedate:[1,3,4,5,3],
#       changenum:[123,567,232,347,122],
#       diamondAgent:[1000000020279926,1000001000010900,1000000020057811,1000000020082392,1000000020174139,1000000020006650,1000000020365763,1000000023088249],
#       diamondAgentPhone:{"1000000020279926":{"virtual_phone_number":"4008958529-6810","phone_number":"17786504949","port":"PC:agent_diamond","virtual_main_number":"4008958529","virtual_ext_number":"6810","fourPhoneOne":"4008958529\u8f6c6810"},"1000001000010900":{"virtual_phone_number":"4008690196-8988","phone_number":"18627773784","port":"PC:agent_ershoufang","virtual_main_number":"4008690196","virtual_ext_number":"8988","fourPhoneOne":"4008690196\u8f6c8988"},"1000000020057811":{"virtual_phone_number":"4008602311-5595","phone_number":"13971455843","port":"PC:agent_ershoufang","virtual_main_number":"4008602311","virtual_ext_number":"5595","fourPhoneOne":"4008602311\u8f6c5595"},"1000000020082392":{"virtual_phone_number":"4008367909-7525","phone_number":"18163534643","port":"PC:agent_ershoufang","virtual_main_number":"4008367909","virtual_ext_number":"7525","fourPhoneOne":"4008367909\u8f6c7525"},"1000000020174139":{"virtual_phone_number":"4008957706-6965","phone_number":"18248605030","port":"PC:agent_ershoufang","virtual_main_number":"4008957706","virtual_ext_number":"6965","fourPhoneOne":"4008957706\u8f6c6965"},"1000000020006650":{"virtual_phone_number":"4008959719-7466","phone_number":"18934658281","port":"PC:agent_ershoufang","virtual_main_number":"4008959719","virtual_ext_number":"7466","fourPhoneOne":"4008959719\u8f6c7466"},"1000000020365763":{"virtual_phone_number":"4008599756-2056","phone_number":"13260553426","port":"PC:agent_ershoufang","virtual_main_number":"4008599756","virtual_ext_number":"2056","fourPhoneOne":"4008599756\u8f6c2056"},"1000000023088249":{"virtual_phone_number":"4008096509-8550","phone_number":"13517198814","port":"PC:agent_ershoufang","virtual_main_number":"4008096509","virtual_ext_number":"8550","fourPhoneOne":"4008096509\u8f6c8550"}},
#       agentInfo:{"1000000020279926":{"ucid":"1000000020279926","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u83ab\u8bd7\u6d0b","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/3fa0348d-8de9-425f-a329-e9829e6d2146.png","agent_url":"https:\/\/dianpu.lianjia.com\/1000000020279926","agent_level":"\u5e97\u7ecf\u7406","feedbackGoodRate":"99%","totalCommentScore":"5.0","commentCount":"70"},"1000001000010900":{"ucid":"1000001000010900","appid":"105","company_name":"\u5fb7\u4f51","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u7f57\u5b9e","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/f1f134a2-fc61-4e74-b652-cf19dd2c4139.jpg","agent_url":"https:\/\/dianpu.lianjia.com\/1000001000010900","agent_level":"\u7ecf\u7eaa\u4eba","feedbackGoodRate":"\u6682\u65e0","totalCommentScore":0,"commentCount":0},"1000000020057811":{"ucid":"1000000020057811","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u672c\u623f\u4fe1\u606f\u7531\u6211\u7ef4\u62a4\uff0c\u6709\u53d8\u5316\u6700\u5feb\u5f97\u77e5","name":"\u8881\u6587\u82b3","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/37415020-b144-41ad-9227-a41b1d31102e.jpg","agent_url":"https:\/\/dianpu.lianjia.com\/1000000020057811","agent_level":"\u9ad8\u7ea7\u7ecf\u7eaa\u4eba","feedbackGoodRate":"100%","totalCommentScore":"5.0","commentCount":"51"},"1000000020082392":{"ucid":"1000000020082392","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u738b\u6167","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/7c4719a5-bddb-4a1b-ae28-64138ce25c0f.jpg","agent_url":"https:\/\/dianpu.lianjia.com\/1000000020082392","agent_level":"\u5e97\u7ecf\u7406","feedbackGoodRate":"100%","totalCommentScore":"5.0","commentCount":"120"},"1000000020174139":{"ucid":"1000000020174139","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u5f20\u70e8","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/e7d20fb6-8aab-44dc-b8bc-8a6f8082fe77.jpg","agent_url":"https:\/\/dianpu.lianjia.com\/1000000020174139","agent_level":"\u9ad8\u7ea7\u7ecf\u7eaa\u4eba","feedbackGoodRate":"100%","totalCommentScore":"5.0","commentCount":"18"},"1000000020006650":{"ucid":"1000000020006650","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u7a0b\u5e86\u82b1","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/816522c2-48b5-4993-b746-4dbfc00e35e1.jpg","agent_url":"https:\/\/dianpu.lianjia.com\/1000000020006650","agent_level":"\u9ad8\u7ea7\u7ecf\u7eaa\u4eba","feedbackGoodRate":"100%","totalCommentScore":"5.0","commentCount":"10"},"1000000020365763":{"ucid":"1000000020365763","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u6768\u5fd7\u5eb7","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/c918cf60-5079-4769-9ea5-35aafff9b07f.jpg","agent_url":"https:\/\/dianpu.lianjia.com\/1000000020365763","agent_level":"\u9ad8\u7ea7\u7ecf\u7eaa\u4eba","feedbackGoodRate":"100%","totalCommentScore":"5.0","commentCount":"17"},"1000000023088249":{"ucid":"1000000023088249","appid":"104","company_name":"\u94fe\u5bb6","isQualify":true,"reason":"\u6211\u5e26\u770b\u8fc7\u672c\u623f\uff0c\u6e05\u695a\u672c\u623f\u7279\u8272","name":"\u962e\u7389\u6d01","photo_url":"https:\/\/image1.ljcdn.com\/usercenter\/images\/uc_ehr_avatar\/848892c2-1e8b-42df-8c79-f731b069f8dc.jpg","agent_ ...
#       hasDaikan:true,
#       uniqueAgent:false,
#       showCart: '1',
#       hasFangjia: false,
#       test_400_hide:'',
#       newTax: false,
#       uuid: 'a766def7-b9dc-4290-ae84-20793c7bfac9',
#       loadingImg: 'https://s1.ljcdn.com/feroot/pc/asset/ershoufang/sellDetail/img/loading.gif?_v=201809070048259',
#       qrImg: '//ajax.api.lianjia.com/qr/getDownloadQr',
#       title: '高层观景房 可望江 中间位置 安静不临街_武汉百步亭银泰御华园一期二手房推荐',
#       images: [{"roomName":"\u5ba2\u5385","roomType":100900000002,"code":1,"id":6400000004518133,"type":"\u5ba2\u5385","uri":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-e2a57ac0-b4c4-4a19-b913-414cb21a48de.png","isHead":1,"isVr":0,"url":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-e2a57ac0-b4c4-4a19-b913-414cb21a48de.png.710x400.jpg"},{"roomName":"\u5ba2\u5385","roomType":100900000002,"code":1,"id":6400000004518137,"type":"\u5ba2\u5385","uri":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-c60fffa0-dda8-4afd-9fa2-678f9570cc51.png","url":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-c60fffa0-dda8-4afd-9fa2-678f9570cc51.png.710x400.jpg"},{"roomName":"\u9910\u5385","roomType":100900000002,"code":1,"id":6400000004518136,"type":"\u9910\u5385","uri":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-0f727b73-ab60-4410-9c36-c90fcdedbb79.png","url":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-0f727b73-ab60-4410-9c36-c90fcdedbb79.png.710x400.jpg"},{"roomName":"\u6237\u578b\u56fe","roomType":99,"code":99,"id":1,"type":"\u6237\u578b\u56fe","fcSort":0,"isOverground":0,"uri":"https:\/\/image1.ljcdn.com\/x-se\/hdic-frame\/test-8d414951-6ccf-400d-a5f9-55023295195e.png","url":"https:\/\/image1.ljcdn.com\/x-se\/hdic-frame\/test-8d414951-6ccf-400d-a5f9-55023295195e.png.533x400.jpg"},{"roomName":"\u5367\u5ba4A","roomType":100900000001,"code":2.1,"id":6400000004518134,"type":"\u5367\u5ba4A","uri":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-7b6feabd-8365-4836-b82a-30f1d75a5ec5.png","url":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-7b6feabd-8365-4836-b82a-30f1d75a5ec5.png.710x400.jpg"},{"roomName":"\u5367\u5ba4B","roomType":100900000001,"code":2.2,"id":6400000004518135,"type":"\u5367\u5ba4B","uri":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-3ed4cb0b-ac94-473b-a590-68997ea388f9.png","url":"https:\/\/image1.ljcdn.com\/420100-inspection\/test-3ed4cb0b-ac94-473b-a590-68997ea388f9.png.710x400.jpg"}],
#       videoId: ''
#     });
#   });
#   require(['common/jquery.popups'], function(){});
#   require(['common/jquery.fly'], function(){});
#   require(['ershoufang/sellDetail/comp/imgZoom'], function(){});
#   require(['common/requestAnimationFrame'], function(){});
#   require(['common/initTalk'], function(initTalk) {
#     initTalk()
#   });
# </script>
# <script>require(['common/suggestion'], function (suggestion) {window.defaultSuggest = suggestion.init({requestOptions: {cityId: '420100',cityName: '武汉'},url: '/api/headerSearch?channel=ershoufang&q=',main: '#keyword-box',appendTo: '#suggest-cont',redirect: true});});</script><div class="loninContaner"><div class="overlay_bg"></div><div class="panel_login animated" id="dialog"><div class="panel_info"><i class="close_login">&amp;times</i><div class="panel_tab"><div class="title"><div class="fl">账号密码登录</div></div><div class="clear"></div><div id="con_login_user"><form action="" method="post"><ul><li class="item border-t userName"><input class="the_input topSpecial users" maxlength="11" placeholder="请输入手机号" type="text"/></li><li class="item border-b pwd"><input class="the_input password" maxlength="20" placeholder="请输入登录密码" type="password"/><em class="password-view"></em></li><li class="item checkVerimg" style="display:none;"><input class="the_input ver-img" maxlength="6" placeholder="请输入验证码" type="text"/><img class="verImg"/></li><li class="item drag" style="display:none;"><div id="drag"></div></li><li class="show-error"><dd>用户名或密码错误</dd></li><li class="li_01"><label class="checkbox-btn"><span class="active"><input checked="" class="mind-login" name="remember" type="checkbox" value="1"/></span>7天内免登录</label><a class="toforget" href="javascript:;" rel="nofollow">忘记密码</a></li><li class="li_btn"><a class="login-user-btn"></a>登录</li><li class="footer-link"><a class="totellogin" href="javascript:;" rel="nofollow">手机快捷登录</a></li></ul></form></div><div class="undis" id="con_login_agent"><form action="" method="post"><ul><li class="item"><dd></dd><input class="the_input users" placeholder="输入经纪人ID号码" type="text"/></li><li class="item"><input class="the_input password" placeholder="登录密码" type="password"/></li><li class="li_01"><label class="checkbox-btn"><span class="active"><input checked="" class="mind-login" name="remember" type="checkbox" value="1"/></span>7天内免登录</label><a href="https://passport.lianjia.com/register/resources/lianjia/forget.html?service=http://bj.lianjia.com/" rel="nofollow">忘记密码</a></li><li><input class="login-agent-btn" value="立即登录"/></li></ul></form></div></div></div><div class="registered"></div></div><div class="panel_login animated" id="dialog_tel"><div class="panel_info"><i class="close_login">&amp;times</i><div class="panel_tab"><div class="title"><div class="fl">手机快捷登录</div><div class="register_text_tel">别担心，无账号自动注册不会导致手机号被泄露</div></div><div class="clear"></div><div id="con_login_user_tel"><form action="" method="post"><ul><li class="item border-t userName"><input class="the_input topSpecial users_tel" maxlength="11" placeholder="请输入手机号" type="text"/></li><!-- <li class="item pwd"><input type="password" class="the_input password_tel"  placeholder="请输入短信验证码"/></li> --><li class="item checkVerimg" style=""><input class="the_input ver-img" maxlength="6" placeholder="请输入验证码" type="text"/><img class="verImg"/></li><li class="item border-b Verify"><input class="the_input verifycode" maxlength="6" placeholder="请输入短信验证码" type="text"/><a class="send_verify_code" href="javascript:;" id="send_verify_code_tel" rel="nofollow"><em>获取验证码</em></a></li><li class="send_verify_code_s" href="javascript:;" id="send_verify_code_tel_s" rel="nofollow"><em>没有收到验证码？</em><a class="voice_a">发送语音验证码</a></li><li class="show-error"><dd>用户名或密码错误</dd></li><li class="li_01"><label class="checkbox-btn"><span class="active"><input checked="" class="mind-login" name="remember" type="checkbox" value="1"/></span>7天内免登录</label></li><li class="li_btn"><a class="login-user-tel-btn"></a>登录</li><li class="footer-link"><a class="tologin" href="javascript:;" rel="nofollow">账号密码登录</a></li></ul></form></div></div></div><div class="registered"></div></div><div class="panel_login animated" id="dialog_reg"><div class="panel_info"><i class="close_login">&amp;times</i><div class="panel_tab"><div class="title"><div class="fl">手机号码注册</div><label class="fr registe ...
# <!-- LianjiaIM Style --><link href="https://s1.ljcdn.com/feroot/pc/asset/lianjiaIM/css/lianjiaim.css?_v=201809070048259" property="stylesheet" rel="stylesheet"/><script src="//s1.ljcdn.com/web-im-sdk/static/1.1/lianjiaim1.1.min.js?v=20180910"></script><!-- <script src="//s1-ljcdn.test.lianjia.com:8400/web-im-sdk/static/1.1/lianjiaim1.1.min.js?v=20180910"></script> --><script>(function() {var imConf = {"ajaxroot":"\/\/ajax.api.lianjia.com\/","imAppid":"LIANJIA_WEB_20160624","imAppkey":"6dfdcee27d78b1107fceeca55d80b7bd"};let login = require('common/login');$.listener.on('userInfo', function (data) {if (data.code === 1) {data.ucid = '';}window.LJIM = new LianjiaIM({appid: imConf.imAppid,appkey: imConf.imAppkey,login: login.openLoginDialog,is_ljbb: true,userData: data,downAppUrl: '//www.lianjia.com/client/',appDesc: '立即下载链家APP，随时随地聊~',staticRoot: 'https://s1.ljcdn.com/feroot/?_v=201809070048259'})});})();</script><script type="text/javascript">var advert = 'https://s1.ljcdn.com/feroot/pc/asset/common/advert.js?_v=201809070048259';
#     $.listener.on('userInfo', function (data) {
#       window.loginData = data;
#     });
#     var mvl = document.createElement('script');
#     mvl.type = 'text/javascript';
#     mvl.async = true;
#     mvl.src = advert;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(mvl, s);
#   </script><script type="text/javascript">(function(){var canonicalURL, curProtocol;var x=document.getElementsByTagName("link");if(x.length > 0){for (i=0;i<x.length;i++){if(x[i].rel.toLowerCase() == 'canonical' && x[i].href){canonicalURL=x[i].href;}}}if (!canonicalURL){curProtocol = window.location.protocol.split(':')[0];}else{curProtocol = canonicalURL.split(':')[0];}if (!canonicalURL) canonicalURL = window.location.href;(function() {var e = /([http|https]:\/\/[a-zA-Z0-9\_\.]+\.baidu\.com)/gi,r = canonicalURL,t = document.referrer;if (!e.test(r)) {var n = (String(curProtocol).toLowerCase() === 'https') ? "https://sp0.baidu.com/9_Q4simg2RQJ8t7jm9iCKT-xh_/s.gif" : "//api.share.baidu.com/s.gif";t ? (n += "?r=" + encodeURIComponent(document.referrer), r && (n += "&l=" + r)) : r && (n += "?l=" + r);var i = new Image;i.src = n}})(window);})();</script><!--cookie mapping--><img alt="cookie_mapping_url" src="https://cm.e.qq.com/cm.fcg?u=248b9273a849b4bc2bfa58b70247d90a&amp;t=1536575724&amp;p=5c99606e17137f322ab017f35b2dab96&amp;platform=PC&amp;gdt_dspid=4169211&amp;gdt_dsp_checksum=5c99606e17137f322ab017f35b2dab96&amp;gdt_dsp_timestamp=1536575724" style="display: none;"/></body></html>

# %%
import os
#for root, dirs, files in os.walk('.', topdown=False):
#    #print(root)
#    #print(dirs)
#    print(files)
#
os.listdir('./lianjia/')
#writeHead('./finalData.csv')
dir = './lianjia/'
for datasource in os.listdir(dir):
    path = dir + datasource
    print(path)
    if os.path.isfile(dir + datasource):
        scrapData(dir + datasource, targetCSVFile = './finalData.csv')
        #print(path)
# Out:
# ./lianjia/baibuting
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a6e6b4cd60fd> in <module>()
#      12     print(path)
#      13     if os.path.isfile(dir + datasource):
# ---> 14         scrapData(dir + datasource, targetCSVFile = './finalData.csv')
#      15         #print(path)
#
# <ipython-input-5-beb32941966a> in scrapData(sourceFile, targetCSVFile)
#      16             html = urlopen(url)
#      17             bsObj = BeautifulSoup(html)
# ---> 18             print(cleanData(bsObj, url))
#      19             #print('正在进行' + url)
#      20             #try:
#
# NameError: name 'cleanData' is not defined
